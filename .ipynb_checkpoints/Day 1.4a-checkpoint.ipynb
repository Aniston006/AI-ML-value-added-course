# %%
pip install -U spacy
# Out:
# ...
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/14.2 MB 10.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.9/14.2 MB 11.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.3/14.2 MB 11.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.1/14.2 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 11.0/14.2 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 12.0 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/653.1 kB ? eta -:--:--
#    ---------------------------------------- 653.1/653.1 kB 9.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 10.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------- ----------------------- 2.6/6.2 MB 13.4 MB/s eta 0:00:01
# ...

# %%
# !python -m spacy download en
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 6.6 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 11.8 MB/s eta 0:00:01
#      ------------------ --------------------- 5.8/12.8 MB 11.8 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 12.1 MB/s eta 0:00:01
#      ------------------------------- ------- 10.5/12.8 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 11.6 MB/s  0:00:01
# ...
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use
# the full pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
doc=nlp(u'Tesla is looking at buying U.S startup for $6 million')
for token in doc:
    print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S PROPN dobj
# startup VERB advcl
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x1d169fe4350>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x1d169fe4530>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x1d169ee7ed0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x1d1662ddf50>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x1d16a005710>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x1d169ee7d10>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2=nlp(u"Tesla isn't   looking into startups anymore.")
for token in doc2:
    print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#    SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2
# Out:
# Tesla isn't   looking into startups anymore.

# %%
doc2[0]
# Out:
# Tesla

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %%
spacy.explain('nsubj')
# Out:
# 'nominal subject'

# %%
print(doc2[4].text)
print(doc2[4].lemma_)
# Out:
# looking
# look

# %%
print(doc2[4].pos_)
print(doc2[4].tag_+' / ' + spacy.explain(doc2[4].tag_))
# Out:
# VERB
# VBG / verb, gerund or present participle

# %%
print(doc2[0].text+' : '+doc2[0].shape_)
print(doc[5].text+' : '+doc[5].shape_)
# Out:
# Tesla : Xxxxx
# U.S : X.X

# %%
print(doc2[0].is_alpha)
print(doc2[0].is_stop)
# Out:
# True
# False

# %%
doc3=nlp(u'Although commonly attributed to john lennon from his song "Beautiful boy",\the phrase "life is what happen to us while we are making other plans"was written by\cartoonist Allen Saunders and published in Readers\nsdigest in 1957,when lennon was 17.')

# %%
life_quote=doc3[16:30]
print(life_quote)
# Out:
# phrase "life is what happen to us while we are making other plans"was

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
doc4=nlp(u'This is the first sentence.This is the second sentence.This is the last sentence.')

# %%
for sent in doc4.sents:
    print(sent)
# Out:
# This is the first sentence.
# This is the second sentence.
# This is the last sentence.

# %%
doc4[6].is_sent_start
# Out:
# True
