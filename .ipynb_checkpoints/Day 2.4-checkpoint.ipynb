# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(u"The Quick brown fox jumper over the lazy dog's back.")
print(doc.text)
# Out:
# The Quick brown fox jumper over the lazy dog's back.

# %%
print(doc[2].text,doc[2].pos_,doc[2].tag_,spacy.explain(doc[2].tag_))
# Out:
# brown ADJ JJ adjective (English), other noun-modifier (Chinese)

# %%
for token in doc:
    print(f"{token.text:{10}}{token.pos_:{8}}{token.tag_:{6}}{spacy.explain(token.tag_)}")
# Out:
# The       DET     DT    determiner
# Quick     ADJ     JJ    adjective (English), other noun-modifier (Chinese)
# brown     ADJ     JJ    adjective (English), other noun-modifier (Chinese)
# fox       NOUN    NN    noun, singular or mass
# jumper    NOUN    NN    noun, singular or mass
# over      ADP     IN    conjunction, subordinating or preposition
# the       DET     DT    determiner
# lazy      ADJ     JJ    adjective (English), other noun-modifier (Chinese)
# dog       NOUN    NN    noun, singular or mass
# 's        PART    POS   possessive ending
# bacl      NOUN    NN    noun, singular or mass
# .         PUNCT   .     punctuation mark, sentence closer

# %%
doc=nlp(u'I read books on NLP')
r=doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBP    verb, non-3rd person singular present

# %%
doc=nlp(u'I read a book on NLP')
r=doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBD    verb, past tense

# %%
Dep_Counts=doc.count_by(spacy.attrs.DEP)
for k,v in sorted(Dep_Counts.items()):
    print(f'{k}.{doc.vocab[k].text:{4}}:{v}')
# Out:
# 415.det :1
# 416.dobj:1
# 429.nsubj:1
# 439.pobj:1
# 443.prep:1
# 8206900633647566924.ROOT:1

# %%
from spacy import displacy

# %%
doc=nlp(u"The quick brown fox jumped over the lazy dog's back")
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{7}} {token.dep_:{7}} {spacy.explain(token.dep_)}')
# Out:
# The        DET     det     determiner
# quick      ADJ     amod    adjectival modifier
# brown      ADJ     amod    adjectival modifier
# fox        NOUN    nsubj   nominal subject
# jumped     VERB    ROOT    root
# over       ADP     prep    prepositional modifier
# the        DET     det     determiner
# lazy       ADJ     amod    adjectival modifier
# dog        NOUN    pobj    object of preposition
# 's         PART    case    case marking
# back       ADV     advmod  adverbial modifier

# %% [markdown]
# displacy.render(doc,style='dep',jupyter=True,options={'distance':110})

# %%
displacy.render(doc,style='dep',jupyter=True,options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="44efc181e72f48f5a42dede90987da9b-0" class="displacy" width="1260" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">back</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-0" stroke-width="2px" d="M70,222.0 C70,57.0 375.0,57.0 375.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L62,212.0 78,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-1" stroke-width="2px" d="M180,222.0 C180,112.0 370.0,112.0 370.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L172,212.0 188,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-2" stroke-width="2px" d="M290,222.0 C290,167.0 365.0,167.0 365.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L282,212.0 298,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-3" stroke-width="2px" d="M400,222.0 C400,167.0 475.0,167.0 475.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,224.0 L392,212.0 408,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-4" stroke-width="2px" d="M510,222.0 C510,167.0 585.0,167.0 585.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585.0,224.0 L593.0,212.0 577.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-5" stroke-width="2px" d="M730,222.0 C730,112.0 920.0,112.0 920.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,224.0 L722,212.0 738,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-6" stroke-width="2px" d="M840,222.0 C840,167.0 915.0,167.0 915.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,224.0 L832,212.0 848,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-7" stroke-width="2px" d="M620,222.0 C620,57.0 925.0,57.0 925.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48f5a42dede90987da9b-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,224.0 L933.0,212.0 917.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44efc181e72f48f5a42dede90987da9b-0-8" stroke-width="2px" d="M950,222.0 C950,167.0 1025.0,167.0 1025.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44efc181e72f48

# %%
doc2=nlp(u"This is a sentence.This is another possible longer sentence.")
spans=list(doc2.sents)
options={'distance':110,'compact':'False','color':'yellow','bg':'#09a3d5','font':'Times'}
displacy.render(doc2,style='dep',jupyter=True,options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="177fe934a46b46e9be0969a073ffc6ec-0" class="displacy" width="1150" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: yellow; background: #09a3d5; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">possible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">longer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-0" stroke-width="2px" d="M62,222.0 62,203.66666666666666 151.0,203.66666666666666 151.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,224.0 L58,216.0 66,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-1" stroke-width="2px" d="M282,222.0 282,203.66666666666666 371.0,203.66666666666666 371.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M282,224.0 L278,216.0 286,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-2" stroke-width="2px" d="M172,222.0 172,185.33333333333334 374.0,185.33333333333334 374.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M374.0,224.0 L378.0,216.0 370.0,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-3" stroke-width="2px" d="M502,222.0 502,203.66666666666666 591.0,203.66666666666666 591.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M502,224.0 L498,216.0 506,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-4" stroke-width="2px" d="M722,222.0 722,167.0 1037.0,167.0 1037.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M722,224.0 L718,216.0 726,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-5" stroke-width="2px" d="M832,222.0 832,185.33333333333334 1034.0,185.33333333333334 1034.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M832,224.0 L828,216.0 836,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-6" stroke-width="2px" d="M942,222.0 942,203.66666666666666 1031.0,203.66666666666666 1031.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M942,224.0 L938,216.0 946,216.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-177fe934a46b46e9be0969a073ffc6ec-0-7" stroke-width="2px" d="M612,222.0 612,148.66666666666669 1040.0,148.66666666666669 1040.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-177fe934a46b46e9be0969a073ffc6ec-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1040.0,224.0 L1044.0,216.0 1036.0,216.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text+'-'+ent.label_+'-'+str(spacy.explain(ent.label_)))
    else:
        print("No named entities found")

# %%
doc=nlp(u'May I go to Washingtion,DC next May to see the Washington Monuments?')
show_ents(doc)
# Out:
# Washingtion-GPE-Countries, cities, states
# DC-GPE-Countries, cities, states
# next May-DATE-Absolute or relative dates or periods
# Washington Monuments-GPE-Countries, cities, states

# %%
doc=nlp(u'Can I please borrow 500 dollars from you to buy some microsoft stock?')
for ent in doc.ents:
    print(ent.text,ent.start,ent.end,ent.start_char,ent.end_char,ent.label_)
# Out:
# 500 dollars 4 6 20 31 MONEY

# %%
doc=nlp(u"Tesla to build U.K. factory for $6 million")
show_ents(doc)
# Out:
# U.K.-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc=nlp(u"Tesla to build U.K. factory for $6 million")
ORG=doc.vocab.strings[u'ORG']
new_ent=spacy.tokens.span.Span(doc,0,1,label=ORG)
doc.ents=list(doc.ents) + [new_ent]
show_ents(doc)
# Out:
# Tesla-ORG-Companies, agencies, institutions, etc.
# U.K.-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc=nlp(u"our company plans to introduce a new vaccum cleaner."u"If Successful,the vaccum cleaner will be our first product.")
show_ents(doc)
# Out:
# Successful-PERSON-People, including fictional
# first-ORDINAL-"first", "second", etc.

# %%
from spacy.matcher import PhraseMatcher
matcher=PhraseMatcher(nlp.vocab)

# %%
doc=nlp(u"our company plans to introduce a new vaccum cleaner."u"If Successful,the vaccum cleaner will be our first product.")
phrase_list=['vaccum cleaner','vaccum_cleaner']
phrase_patterns=[nlp(text)for text in phrase_list]
matcher.add('newProduct',None,*phrase_patterns)
matches=matcher(doc)
matches
# Out:
# [(4452177204818730156, 7, 9), (4452177204818730156, 14, 16)]
