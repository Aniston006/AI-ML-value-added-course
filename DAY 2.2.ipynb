# %% [raw]
# import spacy
# nlp=spacy.load('en_core_wb_sm')

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'after', 'further', 'own', 'sometimes', 'anyway', 'latterly', 'see', 'than', 'of', 'either', 'each', 'never', 'thus', 'we', 'several', 'but', 'would', 'doing', 'make', 'get', 'with', 'now', 'quite', 'using', 'namely', 'among', 'could', 'fifteen', 'whom', 'really', 'herself', '’ll', 'former', 'nevertheless', 'onto', 'during', 'should', 'third', '‘m', 'had', 'hereupon', 'down', 'towards', 'whither', 'ten', 'where', 'almost', 'and', 'our', 'yourselves', '‘d', 'above', 'sixty', 'hundred', 'below', 'thru', 'both', 'any', 'which', 'less', 'yourself', 'other', 'whereas', 'ourselves', 'me', 'four', 'since', 'hers', 'used', 'everywhere', 'serious', 'else', 'another', 'thereby', 'into', 'twenty', 'somehow', 'my', 'n’t', 'beyond', 'every', 'whereupon', 'while', '‘re', 'first', 'all', 'herein', 'nothing', 'except', 'she', 'fifty', 'being', 'you', 'whenever', 'thereafter', 'amongst', 'very', 'more', 'them', 'what', 'regarding', '‘s', 'over', '‘ll', 'before', 'indeed', 'whose', 'about', 'it', 'or', 'may', 'however', 'anyhow', 'something', 'too', 'call', 'somewhere', 'hereby', 'one', 'five', 'between', 'forty', 'last', 'much', 'beforehand', 'front', 'within', 'behind', 'her', 'otherwise', 'because', 'eight', 'everything', 'everyone', 'whereafter', "'ll", 'without', 'how', 'along', 'least', "'re", 'few', 'some', 'such', 'therefore', 'seeming', 'anyone', 'those', 'anything', 'also', 'become', 'up', 'seem', 'eleven', 'was', 'at', 'neither', 'rather', 'he', 'per', 'who', 'full', 'beside', 'part', 'for', 'might', '’s', 'show', 'via', 'next', 'these', 'name', 'if', 'two', 'they', 'your', 'wherever', 'made', 'thereupon', 'why', 'many', 'until', 'us', 'back', 'against', 'whence', 'been', 'seems', 'have', 'bottom', 'already', 'their', 'yours', '‘ve', 'hereafter', 'twelve', 'then', 'there', 'becoming', 'throughout', 'anywhere', 'latter', 'still', 'someone', 'so', "'s", 'are', 'i', '’re', 'upon', 'whereby', 'from', 'his', 'thence', 'say', 'on', 'seemed', 'when', 'him', 'nor', 'across', 'off', 'a', 'others', 'afterwards', 'keep', 'once', 'please', 'to', 'cannot', 'no', 'that', 'yet', 'nowhere', 'do', 'here', 'ca', 'around', 'whole', 'amount', 'six', 'be', 'does', 're', 'just', 'did', "'m", 'though', 'itself', 'side', 'in', 'three', 'again', 'empty', 'an', 'became', "'d", 'alone', 'unless', 'by', 'as', 'n‘t', 'meanwhile', 'give', 'same', 'well', 'move', 'elsewhere', 'the', 'will', 'is', 'mostly', 'noone', 'only', 'through', 'none', 'themselves', 'whatever', 'hence', 'various', 'although', 'its', 'nobody', 'becomes', 'together', 'myself', 'under', 'go', 'most', 'ours', 'besides', '’ve', 'top', 'whoever', 'has', 'whether', 'nine', 'can', 'perhaps', 'always', 'take', 'moreover', 'often', 'toward', "n't", 'not', 'due', '’m', 'sometime', "'ve", 'am', 'were', 'out', 'even', 'formerly', 'done', 'enough', 'wherein', 'therein', 'mine', 'must', '’d', 'ever', 'this', 'put', 'himself'}

# %%
pip show spacy
# Out:
# Name: spacy
# Version: 3.8.11
# Summary: Industrial-strength Natural Language Processing (NLP) in Python
# Home-page: https://spacy.io
# Author: Explosion
# Author-email: contact@explosion.ai
# License: MIT
# Location: C:\Users\Administrator\anaconda3\Lib\site-packages
# Requires: catalogue, cymem, jinja2, murmurhash, numpy, packaging, preshed, pydantic, requests, setuptools, spacy-legacy, spacy-loggers, srsly, thinc, tqdm, typer-slim, wasabi, weasel
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop=True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True
